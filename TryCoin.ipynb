# %%
import os, sys
import hashlib
import datetime

# %%
class Block:
    def __init__(self, index, timestamp, data, previous_hash):
        self.index = index
        self.timestamp = timestamp
        self.data = data
        self.previous_hash = previous_hash
        self.hash = self.compute_hash()
        
    def compute_hash(self):
        hash_engine = hashlib.sha256()
        for data_item in [self.index, self.timestamp, self.data, self.previous_hash]:
            hash_engine.update(str(data_item).encode('ascii'))
        return hash_engine.hexdigest()
    
    def __str__(self):
        return (f"Block(index={self.index}, timestamp={self.timestamp.isoformat()}, "
                f"data={self.data}, previous_hash={self.previous_hash} hash={self.hash})")
    

class BlockChain:
    GENESIS_BLOCK_NAME = "Genesis Block" # name of the Genesis Block (first block in chain)
    CHAIN_NAME = "TryCoinChain"
    __BlockChainStore = []
    
    def create_genesis_block(self):
        '''
        This is first block in the chain. Manually created with index = 0
        '''
        return Block(index=0, timestamp=datetime.datetime.now(), data=self.GENESIS_BLOCK_NAME, previous_hash=0)
        
    def next_block(self, last_block):
        index = last_block.index + 1
        timestamp = datetime.datetime.now()
        data = f"{self.CHAIN_NAME}:{index}"
        previous_hash = last_block.hash
        return Block(index, timestamp, data, previous_hash)
    
    def _add_block(self, block):
        print(f"Adding Block {block}")
        self.__BlockChainStore.append(block)
        
    def __init__(self):
        # initialize with genesis block
        self._add_block(self.create_genesis_block())
    
    def initialize(self, number_of_blocks=20):
        print(f"Adding initial {number_of_blocks} blocks")
        for i in range(number_of_blocks):
            block = self.next_block(self.__BlockChainStore[-1])
            self._add_block(block)
            print("\n")

        

trycoin = BlockChain()
trycoin.initialize()
# Out:
# Adding Block Block(index=0, timestamp=2018-02-01T20:30:26.720059, data=Genesis Block, previous_hash=0 hash=5cf6548ba7cd73d5bf05b455fc19b4627afe83125d6bb1cba0d8f1338e161d71)
# Adding initial 20 blocks
# Adding Block Block(index=1, timestamp=2018-02-01T20:30:26.720059, data=TryCoinChain:1, previous_hash=5cf6548ba7cd73d5bf05b455fc19b4627afe83125d6bb1cba0d8f1338e161d71 hash=bf2234db8b81be61022104bb74a4b04b6b5b0d86751a06396f8b2350235cff73)
#
#
# Adding Block Block(index=2, timestamp=2018-02-01T20:30:26.720059, data=TryCoinChain:2, previous_hash=bf2234db8b81be61022104bb74a4b04b6b5b0d86751a06396f8b2350235cff73 hash=0b8c15ccf40f5ca326cd235aa7517a9db7a0cb97bb93fe4e005ea66605f75dc8)
#
#
# Adding Block Block(index=3, timestamp=2018-02-01T20:30:26.720059, data=TryCoinChain:3, previous_hash=0b8c15ccf40f5ca326cd235aa7517a9db7a0cb97bb93fe4e005ea66605f75dc8 hash=9e87c76ce4c9b2477e0da89825fba09620cc0b481acdc240fbfb9cc4bbbfa761)
#
#
# Adding Block Block(index=4, timestamp=2018-02-01T20:30:26.720059, data=TryCoinChain:4, previous_hash=9e87c76ce4c9b2477e0da89825fba09620cc0b481acdc240fbfb9cc4bbbfa761 hash=fff7c77c34e644fda840047d41baba6468809eb66cb3846504e8c581a9a353d2)
#
#
# Adding Block Block(index=5, timestamp=2018-02-01T20:30:26.720059, data=TryCoinChain:5, previous_hash=fff7c77c34e644fda840047d41baba6468809eb66cb3846504e8c581a9a353d2 hash=c22164e275267ddc6d0a175bf55a6d2d8245b1afe52a5b6d63813c016d6217d4)
#
#
# Adding Block Block(index=6, timestamp=2018-02-01T20:30:26.720059, data=TryCoinChain:6, previous_hash=c22164e275267ddc6d0a175bf55a6d2d8245b1afe52a5b6d63813c016d6217d4 hash=ad003e68a3ea3dc09e584efacd9baf9d244f90bd4bad987c3281657746e42bf8)
#
#
# Adding Block Block(index=7, timestamp=2018-02-01T20:30:26.720059, data=TryCoinChain:7, previous_hash=ad003e68a3ea3dc09e584efacd9baf9d244f90bd4bad987c3281657746e42bf8 hash=ef94f04469dcae94ab8d7317d72d693728eaa8597af8d247ed46c804eec6868d)
#
#
# Adding Block Block(index=8, timestamp=2018-02-01T20:30:26.720059, data=TryCoinChain:8, previous_hash=ef94f04469dcae94ab8d7317d72d693728eaa8597af8d247ed46c804eec6868d hash=acb5440921f3a5cfc28a4ffb5e7a751f36017415bdc8d1e7479e34320e10d649)
#
#
# Adding Block Block(index=9, timestamp=2018-02-01T20:30:26.720059, data=TryCoinChain:9, previous_hash=acb5440921f3a5cfc28a4ffb5e7a751f36017415bdc8d1e7479e34320e10d649 hash=31c6a9466305f3296752b471b5fc1386c76eb0fd85da921394e9beb93aa36755)
#
#
# Adding Block Block(index=10, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:10, previous_hash=31c6a9466305f3296752b471b5fc1386c76eb0fd85da921394e9beb93aa36755 hash=e8db682de70fc3f44e8206476aa89d04f74de51a4c838a9700dc4e96feebbf1c)
#
#
# Adding Block Block(index=11, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:11, previous_hash=e8db682de70fc3f44e8206476aa89d04f74de51a4c838a9700dc4e96feebbf1c hash=a3879f569b67a0358c8c4a15c8a6b3fc3a04be4e38dc63ee0eb806057a85f85b)
#
#
# Adding Block Block(index=12, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:12, previous_hash=a3879f569b67a0358c8c4a15c8a6b3fc3a04be4e38dc63ee0eb806057a85f85b hash=aaba15f3520a1295d781afda86031e9c11a4c68263061d73bed39b2bade99aca)
#
#
# Adding Block Block(index=13, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:13, previous_hash=aaba15f3520a1295d781afda86031e9c11a4c68263061d73bed39b2bade99aca hash=272f254c0b17fe482dcab6ca6ffe3a5491b5171932b6fc3f0a8ec0b44c8d98e9)
#
#
# Adding Block Block(index=14, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:14, previous_hash=272f254c0b17fe482dcab6ca6ffe3a5491b5171932b6fc3f0a8ec0b44c8d98e9 hash=a886a18b5a1df5a07a2912005ffedf8e0bddd9d9c2573552e79a892b0f228b1b)
#
#
# Adding Block Block(index=15, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:15, previous_hash=a886a18b5a1df5a07a2912005ffedf8e0bddd9d9c2573552e79a892b0f228b1b hash=395184fe22db6f908b37e324168474f9d1017a234eb6dc2609fcbc6b4a806361)
#
#
# Adding Block Block(index=16, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:16, previous_hash=395184fe22db6f908b37e324168474f9d1017a234eb6dc2609fcbc6b4a806361 hash=252453b19d12a6218a4ba1c7a280af4d4bffc0cd1299604061890167b1a638e7)
#
#
# Adding Block Block(index=17, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:17, previous_hash=252453b19d12a6218a4ba1c7a280af4d4bffc0cd1299604061890167b1a638e7 hash=9671011da1aec68dda28f9364990444c642030e1e265b5b6043bfacd36ba17ff)
#
#
# Adding Block Block(index=18, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:18, previous_hash=9671011da1aec68dda28f9364990444c642030e1e265b5b6043bfacd36ba17ff hash=20b9de46ac36d0f19530bfc762bff48bb84a7b5988a182060b35293e45ccb738)
#
#
# Adding Block Block(index=19, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:19, previous_hash=20b9de46ac36d0f19530bfc762bff48bb84a7b5988a182060b35293e45ccb738 hash=b21b65d69d57a77a69af0fba877e7bf8b2e51355b3967748cd2e9405b02fcc8c)
#
#
# Adding Block Block(index=20, timestamp=2018-02-01T20:30:26.721049, data=TryCoinChain:20, previous_hash=b21b65d69d57a77a69af0fba877e7bf8b2e51355b3967748cd2e9405b02fcc8c hash=8b41a6b11c17db1324b8344bd9943127e482a4e93a8879989c1d78b4b7c0ab2f)
